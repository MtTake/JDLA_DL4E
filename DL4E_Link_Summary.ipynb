# %% [markdown]
# # 畳み込みニューラルネットワーク

# %% [markdown]
# ## Depwise Separable Convolution
# - [Depthwise Separable Convolutionについて分かりやすく解説！](https://developers.agirobots.com/jp/depthwise-pointwise-convolution/)

# %% [markdown]
#  # 物体検出

# %% [markdown]
# ## R-CNNからFaster R-CNN
# - Qiita  [物体検出モデルの進展 Part1 ~R-CNNからFaster R-CNNまで](https://qiita.com/TaigaHasegawa/items/b05110a2571a5289cbab)

# %% [markdown]
# # ATTENTION

# %% [markdown]
# - Qiita [作って理解する Transformer / Attention](https://qiita.com/halhorn/items/c91497522be27bde17ce)
#
# - Qiita [【深層学習】図で理解するAttention機構](https://qiita.com/ps010/items/0bb2931b666fa602d0fc#:~:text=seq2seq%E3%82%92%E7%94%A8%E3%81%84%E3%81%9F%E6%A9%9F%E6%A2%B0%E7%BF%BB%E8%A8%B3%E3%81%A7%E3%81%AEAttentionseq2seq%E3%82%92%E7%94%A8%E3%81%84%E3%81%9F%E6%A9%9F%E6%A2%B0%E7%BF%BB%E8%A8%B3%E3%81%A7%E3%81%AF%E3%80%81%E3%82%A8%E3%83%B3%E3%82%B3%E3%83%BC%E3%83%80%E3%81%AF%E6%9C%80%E7%B5%82%E3%82%B9%E3%83%86%E3%83%83%E3%83%97%E3%81%AEhidden)

# %% [markdown]
# # VAE GAN

# %% [markdown]
# ## VAE
# - Qiita [Variational Autoencoder徹底解説](https://qiita.com/kenmatsu4/items/b029d697e9995d93aa24)
# - [VAE （(株)シグナルアナリシス）](http://signalanalysis.jp/pdfs/note_VAE.pdf)
#
# ## GAN
#
# ## その他
# - [VAE-GAN発展](https://ssii.jp/ssii/files/2024/technology_map/SSII2024_map_GM.pdf)
